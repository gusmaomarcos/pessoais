# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmaomarcos/pessoais/blob/main/garmin_testes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/drive/MyDrive/Databases/dados_garmin.csv'
df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Tipo de atividade                  20 non-null     object
#  1   Data                               20 non-null     object
#  2   Favorito                           20 non-null     bool
#  3   Título                             20 non-null     object
#  4   Distância                          20 non-null     float64
#  5   Calorias                           20 non-null     object
#  6   Tempo                              20 non-null     object
#  7   FC Média                           20 non-null     object
#  8   FC máxima                          20 non-null     object
#  9   Ritmo médio                        20 non-null     object
#  10  Melhor ritmo                       20 non-null     object
# ...

# %%
df.describe()
# Out:
#        Distância  Subida total  Comprimento médio da passada  \
# count  20.000000     20.000000                           0.0
# mean    9.137500     32.100000                           NaN
# std     5.102322     17.891192                           NaN
# min     1.290000      5.000000                           NaN
# 25%     6.547500     20.750000                           NaN
# 50%     8.145000     29.500000                           NaN
# 75%    12.325000     42.250000                           NaN
# max    21.360000     75.000000                           NaN
#
#        Proporção de média vertical  Oscilação vertical média  \
# count                          0.0                       0.0
# mean                           NaN                       NaN
# std                            NaN                       NaN
# min                            NaN                       NaN
# 25%                            NaN                       NaN
# ...

# %%
df['Distância'].mean().round(2)
# Out:
# 9.14

# %%
df['Tempo'] = pd.to_datetime(df['Tempo'], format='%H:%M:%S')
df['Data'] = df['Tempo'].dt.date
df['Duração'] = df['Tempo'].dt.time
df['Duração'] = df['Duração'].astype(str).apply(pd.to_timedelta)
print(str(df['Duração'].mean().components[1])+':'+str(df['Duração'].mean().components[2])+':'+
      str(df['Duração'].mean().components[3]))
# Out:
# 0:57:18

# %%
df['Duração'].mean().components
# Out:
# Components(days=0, hours=0, minutes=57, seconds=18, milliseconds=950, microseconds=0, nanoseconds=0)

# %%
df['Ritmo médio']
# Out:
# 0      6:10
# 1      5:52
# 2      5:41
# 3      6:41
# 4      6:25
# 5      6:20
# 6      5:49
# 7     19:25
# 8     15:10
# 9      5:57
# 10     5:30
# 11     5:40
# 12     6:19
# 13     6:28
# 14     6:44
# 15     5:37
# 16     5:50
# 17     6:46
# 18     5:41
# 19     6:32
# Name: Ritmo médio, dtype: object
